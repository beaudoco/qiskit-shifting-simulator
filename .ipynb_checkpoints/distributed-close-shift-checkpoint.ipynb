# %%
import openpyxl as xl
from tqdm import tqdm
import time
# import matplotlib.pyplot as plt
from qiskit import *

# %%
## Loading account and backend

# QX_TOKEN = "929e8951d2081e9da2d290c48fc02a9cbd264affbcfc9669a63af613b630a8d545a504adf27d70a6650bf17dfea2fae9400895cb2f0f9f2e4c68466654505723"

# IBMQ.enable_account(QX_TOKEN)
# provider = IBMQ.get_provider(hub='ibm-q-research', group='penn-3', project='main')

# QX_TOKEN = "67313723797a8e1e5905db1cd035fe6918ea028b47a6ab963058182756fbfc7f6b72e92b21c668900e83e60d206de10aec97751d91ef74de7fde33f31e4b4e58"
# provider = IBMQ.enable_account(QX_TOKEN)

# %%
### Chose the backend

# backend = provider.get_backend('ibmq_bogota')
# backend = FakeMelbourne()
backend = Aer.get_backend("qasm_simulator")

# %%
## Initializing the Quantum Circuit

qr = QuantumRegister(15, 'q')
cr = ClassicalRegister(2, 'c')
qc_close = QuantumCircuit(qr, cr)
qc_always_far = QuantumCircuit(qr, cr)
qc_far = QuantumCircuit(qr, cr)

# %%
num_gates = 50 # change this line
q1, q2 = 2, 3
for i in range(num_gates):
    # prepare close 
    qc_close.cx(qr[0], qr[1])
    qc_close.cx(qr[2], qr[3])
    qc_close.barrier()

# %%
# measure for close
qc_close.measure(qr[0], cr[0])
qc_close.measure(qr[1], cr[1])
# qc_close.measure(qr[2], cr[2])
# qc_close.measure(qr[3], cr[3])

# %%
## Executing the Quantum Circuit on a Hardware

max_experiments = 75
circ_list = []
for i in range(max_experiments):
    circ_list.append(qc_close)
    circ_list.append(qc_always_far)
    circ_list.append(qc_far)

# print(circ_list[0])
# print(circ_list[1])
# print(circ_list[2])
# exit()
job = execute(circ_list, backend, shots=8192)
result = job.result()

# %%
t = time.time()

row2 = list(result.get_counts(1).keys())
file_counts = open("counts_num_gates_distributed_{}_{}_far_close.txt".format(num_gates, backend), "a")

if not os.path.exists("distributed_close.xlsx"):
    wb = xl.Workbook()
    ws = wb.active

    row = list(result.get_counts(1).keys())
    row.insert(0, "Backend")
    row.insert(0, "Time")

    ws.append(row)
else:
    wb = xl.load_workbook(filename = "distributed_close.xlsx")
    ws = wb.active

# %%
for k in tqdm(range(max_experiments)):
    print("*************************************************** \
        ***************************************************")
    print("Circuit Index {} {}".format(k, backend), result.get_counts(k))
    print("*************************************************** \
        ***************************************************")

    file_counts.write("{};{};{}\n".format(t, backend, result.get_counts(k)))

    val = result.get_counts(k)
    row = []
    for i in range(len(row2)):
        row.append(val[row2[i]])
    row.insert(0, str(backend))
    row.insert(0, t)
    ws.append(row)     

wb.save("distributed_close.xlsx")
file_counts.close()
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 779.40it/s]
# ***************************************************         ***************************************************
# Circuit Index 0 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 1 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 2 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 3 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 4 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 5 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 6 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 7 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 8 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 9 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 10 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 11 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 12 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 13 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 14 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 15 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 16 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 17 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 18 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 19 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 20 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 21 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 22 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 23 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 24 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 25 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 26 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 27 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 28 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 29 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 30 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 31 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 32 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 33 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 34 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 35 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 36 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 37 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 38 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 39 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 40 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 41 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 42 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 43 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 44 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 45 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 46 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 47 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 48 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 49 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 50 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 51 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 52 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 53 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 54 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 55 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 56 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 57 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 58 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 59 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 60 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 61 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 62 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 63 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 64 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 65 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 66 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 67 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 68 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 69 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 70 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 71 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 72 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 73 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
# ***************************************************         ***************************************************
# Circuit Index 74 qasm_simulator {'00': 8192}
# ***************************************************         ***************************************************
